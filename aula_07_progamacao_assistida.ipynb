# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielvictoraraujodacruz-create/engenharia_de_prompt_aplicacoes_ai/blob/main/aula_07_progamacao_assistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula : Programação assistida
# Gabriel victor / turma de sextou

# %%
# Define uma lista de números
numeros = [0,1,2,3,]

# Calcula a soma de todos os elementos na lista 'numeros' usando a função embutida sum().
# Esta função é mais eficiente e legível do que um loop manual para somar elementos.
soma = sum(numeros)

# Imprime o resultado da soma
print(soma)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21363/3983157343.py in <cell line: 0>()
#       2 soma = 0
#       3 i = 0
# ----> 4 while i < len(numeros):
#       5     soma += numeros[i]
#       6 i+=1
#
# KeyboardInterrupt:

# %% [markdown]
# ### Código Refatorado com Comentários
#
# Aqui está a versão refatorada do seu código, utilizando a função `sum()` para somar os números, que é uma abordagem mais concisa e 'Pythonic'. Os comentários explicam cada etapa.

# %%
# Define uma lista de números
numeros = [1,2,3,]

# Calcula a soma de todos os elementos na lista 'numeros' usando a função embutida sum().
# Esta função é mais eficiente e legível do que um loop manual para somar elementos.
soma = sum(numeros)

# Imprime o resultado da soma
print(soma)
